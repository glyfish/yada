# %% [markdown]
# # Research Library Document List

# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import os
from collections import Counter
from datetime import datetime, timezone


sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))

from apps.agentic.core.document_loaders.research_library_document_loader import ResearchLibraryChromaDocumentLoader
from apps.agentic.core.constants import RESEARCH_LIBRARY_DB_NAME, RESEARCH_LIBRARY_COLLECTION_NAME
from apps.agentic.core.utils import (set_chatgpt_env, set_langsmith_env, set_tavily_env, 
                                     set_github_env, load_research_documents_metadata, load_research_documents)

DB_PATH = "../../.db"
RESEARCH_LIBRARY_FILES_PATH = "../../research_library/research_documents.yml"

set_chatgpt_env(filedir="../../.keys")
set_langsmith_env(filedir="../../.keys")

# %% [markdown]
# ## Configuration

# %%
RESEARCH_LIBRARY_DB_NAME, RESEARCH_LIBRARY_COLLECTION_NAME, DB_PATH, os.listdir(DB_PATH)
# Out:
# ('research_library',
#  'research-library',
#  '../../.db',
#  ['.DS_Store', 'pdf_document_library', 'github'])

# %%
doc_loader = ResearchLibraryChromaDocumentLoader(DB_PATH)
vs = doc_loader.vectorstore
coll = vs._collection
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 doc_loader = ResearchLibraryChromaDocumentLoader(DB_PATH)
#       2 vs = doc_loader.vectorstore
#       3 coll = vs._collection
#
# File ~/Develop/gly.fish/yada/apps/agentic/core/document_loaders/research_library_document_loader.py:43, in ResearchLibraryChromaDocumentLoader.__init__(self, db_path)
#      42 def __init__(self, db_path=DB_PATH):
# ---> 43     super().__init__(RESEARCH_LIBRARY_DB_NAME, RESEARCH_LIBRARY_COLLECTION_NAME, db_path)
#
# File ~/Develop/gly.fish/yada/apps/agentic/core/document_loaders/chroma_document_loader.py:41, in ChromaDocumentLoader.__init__(self, db_name, collection_name, db_path)
#      35 self._db_path = os.path.join(db_path, db_name)
#      36 self._embedding_function = OpenAIEmbeddings(
#      37     embedding_ctx_length=2000,
#      38     chunk_size=100
#      39 )
# ---> 41 self._vectorstore = Chroma(
#      42     collection_name=self._collection_name,
#      43     persist_directory=self._db_path,
#      44     embedding_function=self._embedding_function
#      45 )
#
# File ~/.pyenv/versions/3.11.11/envs/yada-3.11.11/lib/python3.11/site-packages/langchain_chroma/vectorstores.py:370, in Chroma.__init__(self, collection_name, embedding_function, persist_directory, host, port, headers, chroma_cloud_api_key, tenant, database, client_settings, collection_metadata, collection_configuration, client, relevance_score_fn, create_collection_if_not_exists, ssl)
#     368 # PersistentClient
#     369 elif persist_directory is not None:
# --> 370     self._client = chromadb.PersistentClient(
#     371         path=persist_directory,
#     372         settings=_settings,
#     373         tenant=_tenant,
#     374         database=_database,
#     375     )
#     377 # HttpClient
#     378 elif host is not None:
#
# File ~/.pyenv/versions/3.11.11/envs/yada-3.11.11/lib/python3.11/site-packages/chromadb/__init__.py:164, in PersistentClient(path, settings, tenant, database)
#     161 tenant = str(tenant)
#     162 database = str(database)
# --> 164 return ClientCreator(tenant=tenant, database=database, settings=settings)
#
# File ~/.pyenv/versions/3.11.11/envs/yada-3.11.11/lib/python3.11/site-packages/chromadb/api/client.py:87, in Client.__init__(self, tenant, database, settings)
#      85 # Create an admin client for verifying that databases and tenants exist
#      86 self._admin_client = AdminClient.from_system(self._system)
# ---> 87 self._validate_tenant_database(tenant=self.tenant, database=self.database)
#      89 self._submit_client_start_event()
#
# File ~/.pyenv/versions/3.11.11/envs/yada-3.11.11/lib/python3.11/site-packages/chromadb/api/client.py:467, in Client._validate_tenant_database(self, tenant, database)
#     465 # Propagate ChromaErrors
#     466 except ChromaError as e:
# --> 467     raise e
#     468 except Exception:
#     469     raise ValueError(
#     470         f"Could not connect to tenant {tenant}. Are you sure it exists?"
#     471     )
#
# File ~/.pyenv/versions/3.11.11/envs/yada-3.11.11/lib/python3.11/site-packages/chromadb/api/client.py:460, in Client._validate_tenant_database(self, tenant, database)
#     458 def _validate_tenant_database(self, tenant: str, database: str) -> None:
#     459     try:
# --> 460         self._admin_client.get_tenant(name=tenant)
#     461     except httpx.ConnectError:
#     462         raise ValueError(
#     463             "Could not connect to a Chroma server. Are you sure it is running?"
#     464         )
#
# File ~/.pyenv/versions/3.11.11/envs/yada-3.11.11/lib/python3.11/site-packages/chromadb/api/client.py:517, in AdminClient.get_tenant(self, name)
#     515 @override
#     516 def get_tenant(self, name: str) -> Tenant:
# --> 517     return self._server.get_tenant(name=name)
#
# File ~/.pyenv/versions/3.11.11/envs/yada-3.11.11/lib/python3.11/site-packages/chromadb/api/rust.py:165, in RustBindingsAPI.get_tenant(self, name)
#     163 @override
#     164 def get_tenant(self, name: str) -> Tenant:
# --> 165     tenant = self.bindings.get_tenant(name)
#     166     return Tenant(name=tenant.name)
#
# InternalError: Database error: error returned from database: (code: 14) unable to open database file

# %%
client = vs._client
print([c.name for c in client.list_collections()])
print("Opened:", coll.name)
print("total docs:", coll.count())
# Out:
# ['research-library']
# Opened: research-library
# total docs: 1306

# %% [markdown]
# ## Read research_documents.yml

# %%
document_meta_data = load_research_documents_metadata(RESEARCH_LIBRARY_FILES_PATH)
document_meta_data
# Out:
# [{'filename': 'fileanalytic-mechanics-2-e26f51a6-20e3-4f03-a441-234ae51f5317.md',
#   'path': 'research_library/Troy Notes/analytic-mechanics-2-e26f51a6-20e3-4f03-a441-234ae51f5317.md',
#   'title': 'Analytic Mechanics',
#   'authors': 'Troy Stribling',
#   'published_date': '11/12/2018',
#   'topic': 'Review of fundamentals of analytic mechanics.',
#   'tags': 'notes, physics, mechanics'},
#  {'filename': 'carnot-8d44967b-c078-4902-980c-f834d26088a5.md',
#   'path': 'research_library/Jaynes/carnot-8d44967b-c078-4902-980c-f834d26088a5.md',
#   'title': 'The Evolution of Carnot’s Principle',
#   'authors': 'E. T. Jaynes',
#   'published_date': '7/8/1996',
#   'topic': 'Review of historical development of the Second Law of Thermodynamics.',
#   'tags': 'jaynes, thermodynamics'},
#  {'filename': 'autoregessive-proccess-170b6a29-0984-4ad5-892a-08add48c9d89.md',
#   'path': 'research_library/Troy Notes/autoregessive-proccess-170b6a29-0984-4ad5-892a-08add48c9d89.md',
#   'title': 'Autoregressive Processes',
#   'authors': 'Troy Stribling',
#   'published_date': 'Aug 26, 2019',
#   'topic': 'Review of autoregressive model properties, parameter estimation and simulation.',
#   'tags': 'notes, probability, modeling'},
#  {'filename': 'bayesian-data-analysis-3528c615-be76-42cf-8ab8-2db1e49fd5a0.md',
#   'path': 'research_library/Troy Notes/bayesian-data-analysis-3528c615-be76-42cf-8ab8-2db1e49fd5a0.md',
#   'title': 'Bayesian Data Analysis',
#   'authors': 'Troy Stribling',
#   'published_date': 'May 28, 2017',
#   'topic': 'Review of topics in probability involving Bayesian data analysis including sampling and Markov chains.',
#   'tags': 'notes, probability, modeling'},
#  {'filename': 'brownian-motion-16d6b3a0-9781-4a76-807e-15642a39eaeb.md',
#   'path': 'research_library/Troy Notes/brownian-motion-16d6b3a0-9781-4a76-807e-15642a39eaeb.md',
#   'title': 'Brownian Motion',
#   'authors': 'Troy Stribling',
#   'published_date': 'Feb. 5, 2017',
#   'topic': 'Discussion of properties of brownian motion.',
#   'tags': 'notes, probability, modeling'},
#  {'filename': 'discrete-models-of-financial-markets-32910fed-c54c-4930-97d7-5b2113e6f173.md',
#   'path': 'research_library/Troy Notes/discrete-models-of-financial-markets-32910fed-c54c-4930-97d7-5b2113e6f173.md',
#   'title': 'Discrete Models of Financial Markets',
#   'authors': 'Troy Stribling',
#   'published_date': 'May 2, 2021',
#   'topic': 'Discussion of discrete statistical model of finical processes that includes, price modeling, option pricing and portfolio management.',
#   'tags': 'notes, probability, finance'},
#  {'filename': 'fractional-brownian-motion-12cf13ae-5178-43bf-9757-f725893ab74e.md',
#   'path': 'research_library/Troy Notes/fractional-brownian-motion-12cf13ae-5178-43bf-9757-f725893ab74e.md',
#   'title': 'Fractional Brownian Motion',
#   'authors': 'Troy Stribling',
#   'published_date': 'May 2, 2019',
#   'topic': 'Fundamentals of fractional Brownian motion.',
#   'tags': 'notes, probability, modeling'},
#  {'filename': 'functions-volume-1-0fbb7d2a-11cc-4804-aa92-ed83f08bdf62.md',
#   'path': 'research_library/Troy Notes/functions-volume-1-0fbb7d2a-11cc-4804-aa92-ed83f08bdf62.md',
#   'title': 'Functions',
#   'authors': 'Troy Stribling',
#   'published_date': 'Feb. 19, 2017',
#   'topic': 'Discussion of special functions used in mathematical analysis and probability distributions.',
#   'tags': 'notes, math, probability, modeling'},
#  {'filename': 'geometry-a327e4e5-5506-4d05-879d-bb13e58fade1.md',
#   'path': 'research_library/Troy Notes/geometry-a327e4e5-5506-4d05-879d-bb13e58fade1.md',
#   'title': 'Geometry',
#   'authors': 'Troy Stribling',
#   'published_date': 'Jan 30, 2019',
#   'topic': 'Fundamentals of analytic geometry.',
#   'tags': 'notes, math'},
#  {'filename': 'hamiltonian-monte-carlo-daa2ebd1-72df-4f3b-8573-488e0a24ab2a.md',
#   'path': 'research_library/Troy Notes/hamiltonian-monte-carlo-daa2ebd1-72df-4f3b-8573-488e0a24ab2a.md',
#   'title': 'Hamiltonian Monte Carlo',
#   'authors': 'Troy Stribling',
#   'published_date': 'March 23 2019',
#   'topic': 'Detailed analysis of Hamiltonian Monte sampling including derivations and simulations.',
#   'tags': 'notes, math, probability, modeling'},
#  {'filename': 'linear-algebra-bed930cc-fe0d-496a-aa30-634ee36b064d.md',
#   'path': 'research_library/Troy Notes/linear-algebra-bed930cc-fe0d-496a-aa30-634ee36b064d.md',
#   'title': 'Linear Algebra',
#   'authors': 'Troy Stribling',
#   'published_date': 'Jan 30, 2019',
#   'topic': 'Discussion of discrete Fourier transforms.',
#   'tags': 'notes, math'}]

# %%
await load_research_documents(doc_loader, RESEARCH_LIBRARY_FILES_PATH)
# Out:
# INFO:     Create document loader: db_name=research_library, db_path=../../.db, collection_name=research-library.
# ['.DS_Store', 'research_library', 'pdf_document_library', 'github'] /Users/troy/Develop/gly.fish/yada/notebooks/documents ../../.db
# Loading research document: ../../research_library/Troy Notes/analytic-mechanics-2-e26f51a6-20e3-4f03-a441-234ae51f5317.md
# INFO:     Loading research document from ../../research_library/Troy Notes/analytic-mechanics-2-e26f51a6-20e3-4f03-a441-234ae51f5317.md.
# INFO:     Loaded research document into collection research-library: 'Analytic Mechanics' with 87 chunks.
# INFO:     Loaded research document: Analytic Mechanics.
# Loading research document: ../../research_library/Jaynes/carnot-8d44967b-c078-4902-980c-f834d26088a5.md
# INFO:     Loading research document from ../../research_library/Jaynes/carnot-8d44967b-c078-4902-980c-f834d26088a5.md.
# INFO:     Loaded research document into collection research-library: 'The Evolution of Carnot’s Principle' with 52 chunks.
# INFO:     Loaded research document: The Evolution of Carnot’s Principle.
# Loading research document: ../../research_library/Troy Notes/autoregessive-proccess-170b6a29-0984-4ad5-892a-08add48c9d89.md
# INFO:     Loading research document from ../../research_library/Troy Notes/autoregessive-proccess-170b6a29-0984-4ad5-892a-08add48c9d89.md.
# INFO:     Loaded research document into collection research-library: 'Autoregressive Processes' with 278 chunks.
# INFO:     Loaded research document: Autoregressive Processes.
# Loading research document: ../../research_library/Troy Notes/bayesian-data-analysis-3528c615-be76-42cf-8ab8-2db1e49fd5a0.md
# INFO:     Loading research document from ../../research_library/Troy Notes/bayesian-data-analysis-3528c615-be76-42cf-8ab8-2db1e49fd5a0.md.
# INFO:     Loaded research document into collection research-library: 'Bayesian Data Analysis' with 102 chunks.
# INFO:     Loaded research document: Bayesian Data Analysis.
# Loading research document: ../../research_library/Troy Notes/brownian-motion-16d6b3a0-9781-4a76-807e-15642a39eaeb.md
# INFO:     Loading research document from ../../research_library/Troy Notes/brownian-motion-16d6b3a0-9781-4a76-807e-15642a39eaeb.md.
# INFO:     Loaded research document into collection research-library: 'Brownian Motion' with 16 chunks.
# INFO:     Loaded research document: Brownian Motion.
# Loading research document: ../../research_library/Troy Notes/discrete-models-of-financial-markets-32910fed-c54c-4930-97d7-5b2113e6f173.md
# INFO:     Loading research document from ../../research_library/Troy Notes/discrete-models-of-financial-markets-32910fed-c54c-4930-97d7-5b2113e6f173.md.
# INFO:     Loaded research document into collection research-library: 'Discrete Models of Financial Markets' with 250 chunks.
# INFO:     Loaded research document: Discrete Models of Financial Markets.
# Loading research document: ../../research_library/Troy Notes/fractional-brownian-motion-12cf13ae-5178-43bf-9757-f725893ab74e.md
# INFO:     Loading research document from ../../research_library/Troy Notes/fractional-brownian-motion-12cf13ae-5178-43bf-9757-f725893ab74e.md.
# INFO:     Loaded research document into collection research-library: 'Fractional Brownian Motion' with 256 chunks.
# INFO:     Loaded research document: Fractional Brownian Motion.
# Loading research document: ../../research_library/Troy Notes/functions-volume-1-0fbb7d2a-11cc-4804-aa92-ed83f08bdf62.md
# INFO:     Loading research document from ../../research_library/Troy Notes/functions-volume-1-0fbb7d2a-11cc-4804-aa92-ed83f08bdf62.md.
# INFO:     Loaded research document into collection research-library: 'Functions' with 27 chunks.
# INFO:     Loaded research document: Functions.
# Loading research document: ../../research_library/Troy Notes/geometry-a327e4e5-5506-4d05-879d-bb13e58fade1.md
# INFO:     Loading research document from ../../research_library/Troy Notes/geometry-a327e4e5-5506-4d05-879d-bb13e58fade1.md.
# INFO:     Loaded research document into collection research-library: 'Geometry' with 12 chunks.
# INFO:     Loaded research document: Geometry.
# Loading research document: ../../research_library/Troy Notes/hamiltonian-monte-carlo-daa2ebd1-72df-4f3b-8573-488e0a24ab2a.md
# INFO:     Loading research document from ../../research_library/Troy Notes/hamiltonian-monte-carlo-daa2ebd1-72df-4f3b-8573-488e0a24ab2a.md.
# INFO:     Loaded research document into collection research-library: 'Hamiltonian Monte Carlo' with 110 chunks.
# INFO:     Loaded research document: Hamiltonian Monte Carlo.
# Loading research document: ../../research_library/Troy Notes/linear-algebra-bed930cc-fe0d-496a-aa30-634ee36b064d.md
# INFO:     Loading research document from ../../research_library/Troy Notes/linear-algebra-bed930cc-fe0d-496a-aa30-634ee36b064d.md.
# INFO:     Loaded research document into collection research-library: 'Linear Algebra' with 29 chunks.
# INFO:     Loaded research document: Linear Algebra.

# %% [markdown]
# ## Research Notes Metadata

# %%
collection = vs._collection
probe = collection.get(limit=50000)
metas  = [m for m in probe.get("metadatas", []) if m]
len(metas)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[23], line 2
#       1 collection = vs._collection
# ----> 2 probe = collection.get(limit=50000)
#       3 metas  = [m for m in probe.get("metadatas", []) if m]
#       4 len(metas)
#
# File ~/.pyenv/versions/3.11.11/envs/yada-3.11.11/lib/python3.11/site-packages/chromadb/api/models/Collection.py:131, in Collection.get(self, ids, where, limit, offset, where_document, include)
#     109 """Get embeddings and their associate data from the data store. If no ids or where filter is provided returns
#     110 all embeddings up to limit starting at offset.
#     111
#    (...)    122
#     123 """
#     124 get_request = self._validate_and_prepare_get_request(
#     125     ids=ids,
#     126     where=where,
#     127     where_document=where_document,
#     128     include=include,
#     129 )
# --> 131 get_results = self._client._get(
#     132     collection_id=self.id,
#     133     ids=get_request["ids"],
#     134     where=get_request["where"],
#     135     where_document=get_request["where_document"],
#     136     include=get_request["include"],
#     137     limit=limit,
#     138     offset=offset,
#     139     tenant=self.tenant,
#     140     database=self.database,
#     141 )
#     142 return self._transform_get_response(
#     143     response=get_results, include=get_request["include"]
#     144 )
#
# File ~/.pyenv/versions/3.11.11/envs/yada-3.11.11/lib/python3.11/site-packages/chromadb/api/rust.py:363, in RustBindingsAPI._get(self, collection_id, ids, where, limit, offset, where_document, include, tenant, database)
#     351 ids_amount = len(ids) if ids else 0
#     352 self.product_telemetry_client.capture(
#     353     CollectionGetEvent(
#     354         collection_uuid=str(collection_id),
#    (...)    360     )
#     361 )
# --> 363 rust_response = self.bindings.get(
#     364     str(collection_id),
#     365     ids,
#     366     json.dumps(where) if where else None,
#     367     limit,
#     368     offset or 0,
#     369     json.dumps(where_document) if where_document else None,
#     370     include,
#     371     tenant,
#     372     database,
#     373 )
#     375 return GetResult(
#     376     ids=rust_response.ids,
#     377     embeddings=rust_response.embeddings,
#    (...)    382     metadatas=rust_response.metadatas,
#     383 )
#
# InternalError: Database error: error returned from database: (code: 14) unable to open database file

# %%
titles = Counter(m.get("title") for m in metas if "title" in m and m.get("title"))
paths = Counter(m.get("path") for m in metas if "path" in m and m.get("path"))

for title in titles:
    print(f"title counts: {title}")

for path in paths:
    print(f"path counts: {path}")
# Out:
# title counts: Analytic Mechanics
# title counts: The Evolution of Carnot’s Principle
# title counts: Autoregressive Processes
# title counts: Bayesian Data Analysis
# title counts: Brownian Motion
# title counts: Discrete Models of Financial Markets
# title counts: Fractional Brownian Motion
# title counts: Functions
# title counts: Geometry
# title counts: Hamiltonian Monte Carlo
# title counts: Linear Algebra
# path counts: research_library/Troy Notes/analytic-mechanics-2-e26f51a6-20e3-4f03-a441-234ae51f5317.md
# path counts: research_library/Jaynes/carnot-8d44967b-c078-4902-980c-f834d26088a5.md
# path counts: research_library/Troy Notes/autoregessive-proccess-170b6a29-0984-4ad5-892a-08add48c9d89.md
# path counts: research_library/Troy Notes/bayesian-data-analysis-3528c615-be76-42cf-8ab8-2db1e49fd5a0.md
# path counts: research_library/Troy Notes/brownian-motion-16d6b3a0-9781-4a76-807e-15642a39eaeb.md
# path counts: research_library/Troy Notes/discrete-models-of-financial-markets-32910fed-c54c-4930-97d7-5b2113e6f173.md
# path counts: research_library/Troy Notes/fractional-brownian-motion-12cf13ae-5178-43bf-9757-f725893ab74e.md
# path counts: research_library/Troy Notes/functions-volume-1-0fbb7d2a-11cc-4804-aa92-ed83f08bdf62.md
# path counts: research_library/Troy Notes/geometry-a327e4e5-5506-4d05-879d-bb13e58fade1.md
# path counts: research_library/Troy Notes/hamiltonian-monte-carlo-daa2ebd1-72df-4f3b-8573-488e0a24ab2a.md
# path counts: research_library/Troy Notes/linear-algebra-bed930cc-fe0d-496a-aa30-634ee36b064d.md
