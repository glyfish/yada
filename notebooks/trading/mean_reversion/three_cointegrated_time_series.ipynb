# %% [markdown]
# # Analysis of Three Cointegrated Time Series
#
# ## Analysis Procedure
#
# The following modules are used in the analysis.
#
# ```
# from statsmodels.tsa.vector_ar import vecm
# from statsmodels.tsa.stattools import grangercausalitytests
# from statsmodels.tsa.vector_ar.var_model import VAR
# from statsmodels.tsa.vector_ar.vecm import VECM
# ```
#
# The steps to perform the analysis are as follows,
#
# 1. ADF stationarity test all series and difference series until the test pass. This number of differences will define the integration
# order of the system. VECM models are $I(1)$ so should be stationary after one difference.
# 2. Estimate model lags using `VAR.select_order`. Verify with ACF-PACF.
# 3. After the first two steps it will be known that the series are $I(1)$ and the number of lags will be known. `grangercausalitytests` can be applied to the first differences to determine the common trends and suggest the model rank.
# 4. Use the Johansen test from `vecm.coint_johansen` to determine the rank of the model, This should be consistent with the Granger causality results.
# 5. Now estimates for the rank and lag are known and the model parameters can be estimated using `VECM.fit()`. OLS can be used to estimate $\beta$ vectors using time asymptotic form.
# 6. Verify that residual is stationary using ADF test.

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot
from pandas import DataFrame, read_csv

sys.path.insert(0, os.path.abspath('../../..'))

# import local modules
from lib import config
from lib.utils import extract_date_range
from lib.data import ecm, stats, adf, arima, vecm
from lib.plots import comparison, ecm_beta, curve, comparison_stack, stack
from lib.utils import create_ensemble

# Config Plot Style
pyplot.style.use(config.glyfish_style)

# %%
def adf_test(xt):
    for i in range(len(xt)):
        result, _ = adf.compute_adf_offset_test(xt[i])
        result.summary()
        if result.status_vals[1]:
            print("Not Stationary")
        else:
            print("Stationary")

def plot_vecm_simulation(t, xt, title):
    labels = [r"$x_1$", r"$x_2$", r"$x_3$"]   
    comparison(xt, t, labels =labels, title=title, xlabel=r"$t$", lw=1, title_offset=0.05)

def pacf_acf_plot(t, dxt, nlags, title):
    acf = [stats.compute_acf(t, samp, nlags=nlags) for samp in dxt] 
    pacf = [arima.compute_pacf(samp, nlags=nlags) for samp in dxt]
    data = [[acf[i][1], pacf[i][1]] for i in range(len(dxt))]
    time = [[acf[i][0], pacf[i][0]] for i in range(len(dxt))]
    comparison_stack(data, time, title=title, xlabel=r"Lag", ylim=(-0.25, 1.0), figsize=(10, 8), 
                     labels=[["ACF", "PACF"]], ylabels=[r"$\Delta EWA$", r"$\Delta IGE$", r"$\Delta EWC$"])

# %% [markdown]
# ## Analyzed Price Series

# %%
file_path = os.path.abspath('../../../data/algorithmic_trading/EWA.csv')
ewa_data = read_csv(file_path, index_col=0, parse_dates=True).sort_values(by='Date').dropna()
ewa_data.head()
# Out:
#               Open    High     Low   Close  Adj Close  Volume
# Date
# 1996-03-18  10.125  10.125  10.000  10.000   3.283057   35200
# 1996-03-19  10.125  10.125  10.125  10.125   3.324095     500
# 1996-03-20  10.125  10.125  10.125  10.125   3.324095     500
# 1996-03-21  10.250  10.250  10.250  10.250   3.365134   37700
# 1996-03-22  10.250  10.250  10.250  10.250   3.365134     600

# %%
file_path = os.path.abspath('../../../data/algorithmic_trading/EWC.csv')
ewc_data = read_csv(file_path, index_col=0, parse_dates=True).sort_values(by='Date').dropna()
ewc_data.head()
# Out:
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 1996-03-18  10.3125  10.3125  10.3125  10.3125   4.601596     500
# 1996-03-19  10.3750  10.3750  10.3750  10.3750   4.629483     200
# 1996-03-20  10.3750  10.3750  10.3750  10.3750   4.629483       0
# 1996-03-21  10.3750  10.3750  10.3750  10.3750   4.629483       0
# 1996-03-22  10.3750  10.3750  10.3750  10.3750   4.629483       0

# %%
file_path = os.path.abspath('../../../data/algorithmic_trading/IGE.csv')
ige_data = read_csv(file_path, index_col=0, parse_dates=True).sort_values(by='Date').dropna()
ige_data.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2001-11-26  15.168333  15.168333  15.168333  15.168333   9.653491       0
# 2001-11-27  15.168333  15.168333  15.168333  15.168333   9.653491       0
# 2001-11-28  15.168333  15.168333  15.168333  15.168333   9.653491       0
# 2001-11-29  15.168333  15.168333  15.168333  15.168333   9.653491       0
# 2001-11-30  15.220000  15.220000  15.220000  15.220000   9.686371     600

# %%
ewa_date, ewa_close = extract_date_range(ewa_data.index.to_numpy(), ewa_data['Close'].to_numpy(), '2006-04-04', '2012-04-09')
ewc_date, ewc_close = extract_date_range(ewc_data.index.to_numpy(), ewc_data['Close'].to_numpy(), '2006-04-04', '2012-04-09')
ige_date, ige_close = extract_date_range(ige_data.index.to_numpy(), ige_data['Close'].to_numpy(), '2006-04-04', '2012-04-09')

ewa_close_mean = numpy.full(ewa_close.shape, numpy.mean(ewa_close))
ewc_close_mean = numpy.full(ewc_close.shape, numpy.mean(ewc_close))
ige_close_mean = numpy.full(ige_close.shape, numpy.mean(ige_close))

title = f"EWA Share Price, $\mu_{{EWA}} = {numpy.mean(ewa_close):.2f}$"
comparison([ewa_close, ewa_close_mean], [ewa_date, ewa_date], labels=['EWA', r"$\mu_{EWA}$"], title=title, xlabel='Date', ylabel='USD', lw=1)

title = f"EWC Share Price, $\mu_{{EWC}} = {numpy.mean(ewc_close):.2f}$"
comparison([ewc_close, ewc_close_mean], [ewc_date, ewc_date], labels=['EWC', r"$\mu_{EWC}$"], title=title, xlabel='Date', ylabel='USD', lw=1)

title = f"IGE Share Price, $\mu_{{IGE}} = {numpy.mean(ige_close):.2f}$"
comparison([ige_close, ige_close_mean], [ewc_date, ewc_date], labels=['IGE', r"$\mu_{IGE}$"], title=title, xlabel='Date', ylabel='USD', lw=1)

# %%
title = 'EWA, EWC and IGE Share Price'
comparison([ewc_close, ewa_close, ige_close], [ewc_date, ewa_date, ige_date], labels=['EWC', 'EWA', 'IGE'], title=title, xlabel='Date', ylabel='USD', lw=1)

# %%
title = 'EWA, EWC and IGE Share Price Deviation'
ewc_close_dev = ewc_close - numpy.mean(ewc_close)
ewa_close_dev = ewa_close - numpy.mean(ewa_close)
ige_close_dev = ige_close - numpy.mean(ige_close)
comparison([ewc_close_dev, ewa_close_dev, ige_close_dev], [ewc_date, ewa_date, ige_date], labels=['EWC', 'EWA', 'IGE'], title=title, xlabel='Date', ylabel='USD', lw=1)

# %% [markdown]
# ### Stationarity Test
#
# All series are just barely stationary so are close to browninag motion. The first difference is stationary.

# %%
adf_test([ewc_close, ewa_close, ige_close])
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │   -1.98767  │
# ├────────────────┼─────────────┤
# │ pvalue         │    0.292006 │
# ├────────────────┼─────────────┤
# │ Lags           │    0        │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 1513        │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43468 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86345 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56779 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛
# Not Stationary
# ╒════════════════╤═════════════╕
# │ Test Statistic │   -1.89515  │
# ├────────────────┼─────────────┤
# │ pvalue         │    0.334347 │
# ├────────────────┼─────────────┤
# │ Lags           │    1        │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 1512        │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43468 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86345 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56779 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛
# Not Stationary
# ╒════════════════╤═════════════╕
# │ Test Statistic │   -2.14831  │
# ├────────────────┼─────────────┤
# │ pvalue         │    0.225537 │
# ├────────────────┼─────────────┤
# │ Lags           │    1        │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 1512        │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43468 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86345 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56779 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛
# Not Stationary

# %%
dt, dxt = stats.compute_diff(ewa_date, numpy.array([ewa_close, ige_close, ewc_close]))
adf_test(dxt)
# Out:
# ╒════════════════╤═══════════╕
# │ Test Statistic │  -43.6018 │
# ├────────────────┼───────────┤
# │ pvalue         │    0      │
# ├────────────────┼───────────┤
# │ Lags           │    0      │
# ├────────────────┼───────────┤
# │ Number Obs     │ 1512      │
# ╘════════════════╧═══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43468 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86345 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56779 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛
# Stationary
# ╒════════════════╤═══════════╕
# │ Test Statistic │  -29.1233 │
# ├────────────────┼───────────┤
# │ pvalue         │    0      │
# ├────────────────┼───────────┤
# │ Lags           │    1      │
# ├────────────────┼───────────┤
# │ Number Obs     │ 1511      │
# ╘════════════════╧═══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43469 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86345 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56779 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛
# Stationary
# ╒════════════════╤═══════════╕
# │ Test Statistic │  -39.2856 │
# ├────────────────┼───────────┤
# │ pvalue         │    0      │
# ├────────────────┼───────────┤
# │ Lags           │    0      │
# ├────────────────┼───────────┤
# │ Number Obs     │ 1512      │
# ╘════════════════╧═══════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43468 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86345 │ Failed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56779 │ Failed   │
# ╘════════════════╧══════════════════╧══════════╛
# Stationary

# %%
title = 'EWA, EWC and IGE Delta Share Price'
labels = [r"$\Delta\ EWA$", r"$\Delta\ IGE$", r"$\Delta\ EWC$"]   
stack(dxt, title=title, ylabels=labels, xlabel=r"$t$", lw=1, title_offset=0.05, figsize=(10, 8))

# %% [markdown]
# ### Order Determination
#
# All series are close to havong order 1.

# %%
result, result_model = vecm.compute_order(numpy.array([ewa_close, ige_close, ewc_close]), maxlags=4)
result.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#    "_VAROrderTestReport__test_id": "38fe1741-5877-4144-b964-e89124249c74",
#    "_VAROrderTestReport__order": {
#       "test_id": "38fe1741-5877-4144-b964-e89124249c74",
#       "label": "$\\tau_{min}$",
#       "value": 1
#    },
#    "_VAROrderTestReport__aic": {
#       "test_id": "38fe1741-5877-4144-b964-e89124249c74",
#       "order": {
#          "test_id": "38fe1741-5877-4144-b964-e89124249c74",
#          "label": "$\\tau_{AIC}$",
#          "value": 2
#       },
#       "error_metric": "AIC",
#       "value": {
#          "test_id": "38fe1741-5877-4144-b964-e89124249c74",
#          "label": "$\\varepsilon_{AIC}$",
#          "value": -6.327368024360867
#       }
#    },
#    "_VAROrderTestReport__bic": {
#       "test_id": "38fe1741-5877-4144-b964-e89124249c74",
#       "order": {
#          "test_id": "38fe1741-5877-4144-b964-e89124249c74",
#          "label": "$\\tau_{BIC}$",
#          "value": 1
#       },
#       "error_metric": "BIC",
#       "value": {
#          "test_id": "38fe1741-5877-4144-b964-e89124249c74",
#          "label": "$\\varepsilon_{BIC}$",
#          "value": -6.211043517310277
#       }
#    },
#    "_VAROrderTestReport__fpe": {
#       "test_id": "38fe1741-5877-4144-b964-e89124249c74",
#       "order": {
#          "test_id": "38fe1741-5877-4144-b964-e89124249c74",
#          "label": "$\\tau_{FPE}$",
#          "value": 2
#       },
#       "error_metric": "FPE",
#       "value": {
#          "test_id": "38fe1741-5877-4144-b964-e89124249c74",
#          "label": "$\\varepsilon_{FPE}$",
#          "value": 0.0017867316005722475
#       }
#    },
#    "_VAROrderTestReport__hqic": {
#       "test_id": "38fe1741-5877-4144-b964-e89124249c74",
#       "order": {
#          "test_id": "38fe1741-5877-4144-b964-e89124249c74",
#          "label": "$\\tau_{HQIC}$",
#          "value": 1
#       },
#       "error_metric": "HQIC",
#       "value": {
#          "test_id": "38fe1741-5877-4144-b964-e89124249c74",
#          "label": "$\\varepsilon_{HQIC}$",
#          "value": -6.2840458969195625
#       }
#    }
# }

# %%
nlags = 10
title = f"ACF and PACF of EWA, EWC and IGE Delta ACF and PACF"
pacf_acf_plot(numpy.arange(0, len(dxt[0])), dxt, 10, title)

# %% [markdown]
# ### Granger Causality
#
# The Granger causalty analysis is the same as for the EWA-EWC analysis. If two lags are assumed EWA is causal to EWC and close to casing IGE.

# %%
result, result_model = stats.compute_causality_matrix(dxt, nlags=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=1509, df_num=1
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=1
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=1
# parameter F test:         F=20.0580 , p=0.0000  , df_denom=1509, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=1508, df_num=2
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=2
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=2
# parameter F test:         F=10.1065 , p=0.0000  , df_denom=1508, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1490  , p=0.6995  , df_denom=1509, df_num=1
# ssr based chi2 test:   chi2=0.1493  , p=0.6992  , df=1
# likelihood ratio test: chi2=0.1493  , p=0.6992  , df=1
# parameter F test:         F=0.1490  , p=0.6995  , df_denom=1509, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3068  , p=0.7358  , df_denom=1506, df_num=2
# ssr based chi2 test:   chi2=0.6156  , p=0.7350  , df=2
# likelihood ratio test: chi2=0.6155  , p=0.7351  , df=2
# parameter F test:         F=0.3068  , p=0.7358  , df_denom=1506, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.6738  , p=0.0555  , df_denom=1509, df_num=1
# ssr based chi2 test:   chi2=3.6811  , p=0.0550  , df=1
# likelihood ratio test: chi2=3.6766  , p=0.0552  , df=1
# parameter F test:         F=3.6738  , p=0.0555  , df_denom=1509, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.1819  , p=0.0057  , df_denom=1506, df_num=2
# ssr based chi2 test:   chi2=10.3982 , p=0.0055  , df=2
# likelihood ratio test: chi2=10.3626 , p=0.0056  , df=2
# parameter F test:         F=5.1819  , p=0.0057  , df_denom=1506, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2405  , p=0.6239  , df_denom=1509, df_num=1
# ssr based chi2 test:   chi2=0.2409  , p=0.6235  , df=1
# likelihood ratio test: chi2=0.2409  , p=0.6235  , df=1
# parameter F test:         F=0.2405  , p=0.6239  , df_denom=1509, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4295  , p=0.6509  , df_denom=1506, df_num=2
# ssr based chi2 test:   chi2=0.8618  , p=0.6499  , df=2
# likelihood ratio test: chi2=0.8616  , p=0.6500  , df=2
# parameter F test:         F=0.4295  , p=0.6509  , df_denom=1506, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=1510, df_num=1
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=1
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=1
# parameter F test:         F=3.0932  , p=0.0788  , df_denom=1510, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=1508, df_num=2
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=2
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=2
# parameter F test:         F=2.5795  , p=0.0761  , df_denom=1508, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6274  , p=0.4284  , df_denom=1509, df_num=1
# ssr based chi2 test:   chi2=0.6286  , p=0.4279  , df=1
# likelihood ratio test: chi2=0.6285  , p=0.4279  , df=1
# parameter F test:         F=0.6274  , p=0.4284  , df_denom=1509, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3755  , p=0.2530  , df_denom=1506, df_num=2
# ssr based chi2 test:   chi2=2.7600  , p=0.2516  , df=2
# likelihood ratio test: chi2=2.7575  , p=0.2519  , df=2
# parameter F test:         F=1.3755  , p=0.2530  , df_denom=1506, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1258  , p=0.7229  , df_denom=1509, df_num=1
# ssr based chi2 test:   chi2=0.1260  , p=0.7226  , df=1
# likelihood ratio test: chi2=0.1260  , p=0.7226  , df=1
# parameter F test:         F=0.1258  , p=0.7229  , df_denom=1509, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1789  , p=0.8362  , df_denom=1506, df_num=2
# ssr based chi2 test:   chi2=0.3590  , p=0.8357  , df=2
# likelihood ratio test: chi2=0.3589  , p=0.8357  , df=2
# parameter F test:         F=0.1789  , p=0.8362  , df_denom=1506, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4283  , p=0.5129  , df_denom=1509, df_num=1
# ssr based chi2 test:   chi2=0.4292  , p=0.5124  , df=1
# likelihood ratio test: chi2=0.4291  , p=0.5124  , df=1
# parameter F test:         F=0.4283  , p=0.5129  , df_denom=1509, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6504  , p=0.5220  , df_denom=1506, df_num=2
# ssr based chi2 test:   chi2=1.3051  , p=0.5207  , df=2
# likelihood ratio test: chi2=1.3045  , p=0.5209  , df=2
# parameter F test:         F=0.6504  , p=0.5220  , df_denom=1506, df_num=2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=1510, df_num=1
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=1
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=1
# parameter F test:         F=0.1787  , p=0.6726  , df_denom=1510, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=1508, df_num=2
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=2
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=2
# parameter F test:         F=0.1810  , p=0.8345  , df_denom=1508, df_num=2

# %%
result.head(10)
# Out:
#    pvalue  critical_value  result  dependent_var  causal_var
# 1  1.0000            0.05   False              1           1
# 2  0.6995            0.05   False              1           2
# 3  0.0057            0.05    True              1           3
# 4  0.6239            0.05   False              2           1
# 5  1.0000            0.05   False              2           2
# 6  0.2530            0.05   False              2           3
# 7  0.7229            0.05   False              3           1
# 8  0.5129            0.05   False              3           2
# 9  1.0000            0.05   False              3           3

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#    "test_id": "8968a8b9-b438-4c67-a32d-b93500edce46",
#    "rank": 1,
#    "results": [
#       {
#          "_GrangerCausalityTestResult__est_id": "8968a8b9-b438-4c67-a32d-b93500edce46",
#          "_GrangerCausalityTestResult__dependent_var": 1,
#          "_GrangerCausalityTestResult__causal_var": 1,
#          "_GrangerCausalityTestResult__pvalue": 1.0,
#          "_GrangerCausalityTestResult__critical_value": 0.05,
#          "_GrangerCausalityTestResult__result": false
#       },
#       {
#          "_GrangerCausalityTestResult__est_id": "8968a8b9-b438-4c67-a32d-b93500edce46",
#          "_GrangerCausalityTestResult__dependent_var": 1,
#          "_GrangerCausalityTestResult__causal_var": 2,
#          "_GrangerCausalityTestResult__pvalue": 0.7229,
#          "_GrangerCausalityTestResult__critical_value": 0.05,
#          "_GrangerCausalityTestResult__result": false
#       },
#       {
#          "_GrangerCausalityTestResult__est_id": "8968a8b9-b438-4c67-a32d-b93500edce46",
#          "_GrangerCausalityTestResult__dependent_var": 1,
#          "_GrangerCausalityTestResult__causal_var": 3,
#          "_GrangerCausalityTestResult__pvalue": 0.5129,
#          "_GrangerCausalityTestResult__critical_value": 0.05,
#          "_GrangerCausalityTestResult__result": false
#       },
#       {
#          "_GrangerCausalityTestResult__est_id": "8968a8b9-b438-4c67-a32d-b93500edce46",
#          "_GrangerCausalityTestResult__dependent_var": 2,
#          "_GrangerCausalityTestResult__causal_var": 1,
#          "_GrangerCausalityTestResult__pvalue": 0.0057,
#          "_GrangerCausalityTestResult__critical_value": 0.05,
#          "_GrangerCausalityTestResult__result": true
#       },
#       {
#          "_GrangerCausalityTestResult__est_id": "8968a8b9-b438-4c67-a32d-b93500edce46",
#          "_GrangerCausalityTestResult__dependent_var": 2,
#          "_GrangerCausalityTestResult__causal_var": 2,
#          "_GrangerCausalityTestResult__pvalue": 1.0,
#          "_GrangerCausalityTestResult__critical_value": 0.05,
#          "_GrangerCausalityTestResult__result": false
#       },
#       {
#          "_GrangerCausalityTestResult__est_id": "8968a8b9-b438-4c67-a32d-b93500edce46",
#          "_GrangerCausalityTestResult__dependent_var": 2,
#          "_GrangerCausalityTestResult__causal_var": 3,
#          "_GrangerCausalityTestResult__pvalue": 0.6995,
#          "_GrangerCausalityTestResult__critical_value": 0.05,
#          "_GrangerCausalityTestResult__result": false
#       },
#       {
#          "_GrangerCausalityTestResult__est_id": "8968a8b9-b438-4c67-a32d-b93500edce46",
#          "_GrangerCausalityTestResult__dependent_var": 3,
#          "_GrangerCausalityTestResult__causal_var": 1,
#          "_GrangerCausalityTestResult__pvalue": 0.253,
#          "_GrangerCausalityTestResult__critical_value": 0.05,
#          "_GrangerCausalityTestResult__result": false
#       },
#       {
#          "_GrangerCausalityTestResult__est_id": "8968a8b9-b438-4c67-a32d-b93500edce46",
#          "_GrangerCausalityTestResult__dependent_var": 3,
#          "_GrangerCausalityTestResult__causal_var": 2,
#          "_GrangerCausalityTestResult__pvalue": 0.6239,
#          "_GrangerCausalityTestResult__critical_value": 0.05,
#          "_GrangerCausalityTestResult__result": false
#       },
#       {
#          "_GrangerCausalityTestResult__est_id": "8968a8b9-b438-4c67-a32d-b93500edce46",
#          "_GrangerCausalityTestResult__dependent_var": 3,
#          "_GrangerCausalityTestResult__causal_var": 3,
#          "_GrangerCausalityTestResult__pvalue": 1.0,
#          "_GrangerCausalityTestResult__critical_value": 0.05,
#          "_GrangerCausalityTestResult__result": false
#       }
#    ]
# }

# %% [markdown]
# ### Johansen Test for Cointegration

# %%
result, result_model, _ = vecm.compute_johansen_coint_test(numpy.array([ewa_close, ige_close, ewc_close]), 1)

# %%
result.summary()
# Out:
# Trace Statistic
# ╒═══════════════════╤══════════════════╤══════════════════════╤══════════════════════╤══════════════════════╕
# │ Null Hypothesis   │   Test Statistic │   Critical Value 90% │   Critical Value 95% │   Critical Value 99% │
# ╞═══════════════════╪══════════════════╪══════════════════════╪══════════════════════╪══════════════════════╡
# │ r <= 0            │           28.242 │               27.067 │               29.796 │               35.463 │
# ├───────────────────┼──────────────────┼──────────────────────┼──────────────────────┼──────────────────────┤
# │ r <= 1            │           14.036 │               13.429 │               15.494 │               19.935 │
# ├───────────────────┼──────────────────┼──────────────────────┼──────────────────────┼──────────────────────┤
# │ r <= 2            │            4.577 │                2.705 │                3.841 │                6.635 │
# ╘═══════════════════╧══════════════════╧══════════════════════╧══════════════════════╧══════════════════════╛
#
# Rank
# ╒══════════════════════╤══════════════════════╤══════════════════════╕
# │   Critical Value 90% │   Critical Value 95% │   Critical Value 99% │
# ╞══════════════════════╪══════════════════════╪══════════════════════╡
# │                    3 │                    3 │                    0 │
# ╘══════════════════════╧══════════════════════╧══════════════════════╛
#
# Eigenvalue Statistic
# ╒═══════════════════╤══════════════════╤══════════════════════╤══════════════════════╤══════════════════════╕
# │ Null Hypothesis   │   Test Statistic │   Critical Value 90% │   Critical Value 95% │   Critical Value 99% │
# ╞═══════════════════╪══════════════════╪══════════════════════╪══════════════════════╪══════════════════════╡
# │ r <= 0            │           14.206 │               18.893 │               21.131 │               25.865 │
# ├───────────────────┼──────────────────┼──────────────────────┼──────────────────────┼──────────────────────┤
# │ r <= 1            │            9.459 │               12.297 │               14.264 │               18.520 │
# ├───────────────────┼──────────────────┼──────────────────────┼──────────────────────┼──────────────────────┤
# │ r <= 2            │            4.577 │                2.705 │                3.841 │                6.635 │
# ╘═══════════════════╧══════════════════╧══════════════════════╧══════════════════════╧══════════════════════╛
#
# Eigenvalues and Eigenvectors
# ╒═══════════════╤═══════════════════════════════════════╕
# │   Eigen Value │ Eigen Vector                          │
# ╞═══════════════╪═══════════════════════════════════════╡
# │      9.35e-03 │ [ 0.22984234  0.56573759 -0.94922607] │
# ├───────────────┼───────────────────────────────────────┤
# │      6.24e-03 │ [-0.53304247  0.07198318  0.44026791] │
# ├───────────────┼───────────────────────────────────────┤
# │      3.02e-03 │ [ 0.08534551 -0.10990232  0.28342326] │
# ╘═══════════════╧═══════════════════════════════════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#    "test_id": "38981ff2-0afe-44d7-bf16-248268af3589",
#    "trace_test": [
#       {
#          "test_id": "38981ff2-0afe-44d7-bf16-248268af3589",
#          "test_rank": 0,
#          "null_hypothesis": "r<=0",
#          "test_stat": 28.241769454593534,
#          "critical_values": [
#             27.0669,
#             29.7961,
#             35.4628
#          ],
#          "significance_levels": [
#             "Critical Value 90%",
#             "Critical Value 95%",
#             "Critical Value 99%"
#          ],
#          "test_result": [
#             true,
#             false,
#             false
#          ]
#       },
#       {
#          "test_id": "38981ff2-0afe-44d7-bf16-248268af3589",
#          "test_rank": 1,
#          "null_hypothesis": "r<=1",
#          "test_stat": 14.035632195923275,
#          "critical_values": [
#             13.4294,
#             15.4943,
#             19.9349
#          ],
#          "significance_levels": [
#             "Critical Value 90%",
#             "Critical Value 95%",
#             "Critical Value 99%"
#          ],
#          "test_result": [
#             true,
#             false,
#             false
#          ]
#       },
#       {
#          "test_id": "38981ff2-0afe-44d7-bf16-248268af3589",
#          "test_rank": 2,
#          "null_hypothesis": "r<=2",
#          "test_stat": 4.57709056941779,
#          "critical_values": [
#             2.7055,
#             3.8415,
#             6.6349
#          ],
#          "significance_levels": [
#             "Critical Value 90%",
#             "Critical Value 95%",
#             "Critical Value 99%"
#          ],
#          "test_result": [
#             true,
#             true,
#             false
#          ]
#       }
#    ],
#    "eigen_test": [
#       {
#          "test_id": "38981ff2-0afe-44d7-bf16-248268af3589",
#          "test_rank": 0,
#          "null_hypothesis": "r<=0",
#          "test_stat": 14.206137258670262,
#          "critical_values": [
#             18.8928,
#             21.1314,
#             25.865
#          ],
#          "significance_levels": [
#             "Critical Value 90%",
#             "Critical Value 95%",
#             "Critical Value 99%"
#          ],
#          "test_result": [
#             false,
#             false,
#             false
#          ]
#       },
#       {
#          "test_id": "38981ff2-0afe-44d7-bf16-248268af3589",
#          "test_rank": 1,
#          "null_hypothesis": "r<=1",
#          "test_stat": 9.458541626505484,
#          "critical_values": [
#             12.2971,
#             14.2639,
#             18.52
#          ],
#          "significance_levels": [
#             "Critical Value 90%",
#             "Critical Value 95%",
#             "Critical Value 99%"
#          ],
#          "test_result": [
#             false,
#             false,
#             false
#          ]
#       },
#       {
#          "test_id": "38981ff2-0afe-44d7-bf16-248268af3589",
#          "test_rank": 2,
#          "null_hypothesis": "r<=2",
#          "test_stat": 4.57709056941779,
#          "critical_values": [
#             2.7055,
#             3.8415,
#             6.6349
#          ],
#          "significance_levels": [
#             "Critical Value 90%",
#             "Critical Value 95%",
#             "Critical Value 99%"
#          ],
#          "test_result": [
#             true,
#             true,
#             false
#          ]
#       }
#    ],
#    "ranks": {
#       "test_id": "38981ff2-0afe-44d7-bf16-248268af3589",
#       "test_ranks": [
#          3,
#          1,
#          0
#       ],
#       "significance_levels": [
#          "Critical Value 90%",
#          "Critical Value 95%",
#          "Critical Value 99%"
#       ]
#    },
#    "eigen_vectors": [
#       {
#          "test_id": "38981ff2-0afe-44d7-bf16-248268af3589",
#          "eigen_value": 0.009351592749124234,
#          "eigen_vector": [
#             0.9492260667169357,
#             0.44026791379079894,
#             -0.2834232572881703
#          ]
#       },
#       {
#          "test_id": "38981ff2-0afe-44d7-bf16-248268af3589",
#          "eigen_value": 0.006236123387084764,
#          "eigen_vector": [
#             -0.22984234057980263,
#             -0.5330424650101133,
#             -0.08534550833002734
#          ]
#       },
#       {
#          "test_id": "38981ff2-0afe-44d7-bf16-248268af3589",
#          "eigen_value": 0.0030225990242494466,
#          "eigen_vector": [
#             -0.5657375944371658,
#             0.07198317838820126,
#             0.10990232143072559
#          ]
#       }
#    ],
#    "rank": 0
# }

# %% [markdown]
# ### VECM Parameter Estimation

# %%
result, result_model = vecm.compute_estimate(numpy.array([ewa_close, ige_close, ewc_close]), maxlags=1, rank=2)
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
# Det. terms outside the coint. relation & lagged endog. parameters for equation y1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0294      0.030      0.968      0.333      -0.030       0.089
# L1.y1         -0.1618      0.042     -3.833      0.000      -0.245      -0.079
# L1.y2         -0.0926      0.038     -2.424      0.015      -0.167      -0.018
# L1.y3          0.2083      0.067      3.105      0.002       0.077       0.340
# Det. terms outside the coint. relation & lagged endog. parameters for equation y2
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1152      0.047      2.474      0.013       0.024       0.206
# L1.y1         -0.0018      0.065     -0.028      0.978      -0.129       0.125
# L1.y2         -0.0739      0.059     -1.263      0.206      -0.189       0.041
# L1.y3          0.0576      0.103      0.561      0.575      -0.144       0.259
# Det. terms outside the coint. relation & lagged endog. parameters for equation y3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0633      0.029      2.221      0.026       0.007       0.119
# L1.y1          0.0019      0.040      0.049      0.961      -0.076       0.080
# L1.y2          0.0257      0.036      0.717      0.474      -0.045       0.096
# L1.y3         -0.0508      0.063     -0.807      0.420      -0.174       0.073
#                  Loading coefficients (alpha) for equation y1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.0028      0.007     -0.391      0.696      -0.017       0.011
# ec2           -0.0182      0.007     -2.588      0.010      -0.032      -0.004
#                  Loading coefficients (alpha) for equation y2
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            0.0140      0.011      1.276      0.202      -0.008       0.036
# ec2           -0.0268      0.011     -2.486      0.013      -0.048      -0.006
#                  Loading coefficients (alpha) for equation y3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            0.0107      0.007      1.589      0.112      -0.002       0.024
# ec2           -0.0091      0.007     -1.381      0.167      -0.022       0.004
#           Cointegration relations for loading-coefficients-column 1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1         1.0000          0          0      0.000       1.000       1.000
# beta.2     -2.376e-18          0          0      0.000   -2.38e-18   -2.38e-18
# beta.3        -0.9978      0.128     -7.812      0.000      -1.248      -0.747
#           Cointegration relations for loading-coefficients-column 2
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1      1.527e-17          0          0      0.000    1.53e-17    1.53e-17
# beta.2         1.0000          0          0      0.000       1.000       1.000
# beta.3        -1.2725      0.110    -11.526      0.000      -1.489      -1.056
# ==============================================================================
# """

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#    "est_model": "VECM",
#    "rank": 2,
#    "const": [
#       {
#          "est": 0.029414280902089262,
#          "err": 0.030382544476460757,
#          "est_label": "$\\hat{M}$",
#          "err_label": "$\\sigma_{M}$",
#          "row": 0,
#          "column": 0,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_CONST"
#       },
#       {
#          "est": 0.11516190969403423,
#          "err": 0.04655160990622478,
#          "est_label": "$\\hat{M}$",
#          "err_label": "$\\sigma_{M}$",
#          "row": 1,
#          "column": 0,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_CONST"
#       },
#       {
#          "est": 0.06333836089409339,
#          "err": 0.028514690598421467,
#          "est_label": "$\\hat{M}$",
#          "err_label": "$\\sigma_{M}$",
#          "row": 2,
#          "column": 0,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_CONST"
#       }
#    ],
#    "order": 1,
#    "lambda_est": [
#       {
#          "est": -0.002800510286082659,
#          "err": 0.007164911384565564,
#          "est_label": "$\\hat{\\lambda}$",
#          "err_label": "$\\sigma_{\\lambda}$",
#          "row": 0,
#          "column": 0,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_LAMBDA"
#       },
#       {
#          "est": 0.014009989734589948,
#          "err": 0.010977953477378358,
#          "est_label": "$\\hat{\\lambda}$",
#          "err_label": "$\\sigma_{\\lambda}$",
#          "row": 1,
#          "column": 0,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_LAMBDA"
#       },
#       {
#          "est": 0.010681900185810179,
#          "err": 0.006724427950867728,
#          "est_label": "$\\hat{\\lambda}$",
#          "err_label": "$\\sigma_{\\lambda}$",
#          "row": 2,
#          "column": 0,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_LAMBDA"
#       },
#       {
#          "est": -0.01821458469296902,
#          "err": 0.007039193224201364,
#          "est_label": "$\\hat{\\lambda}$",
#          "err_label": "$\\sigma_{\\lambda}$",
#          "row": 0,
#          "column": 1,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_LAMBDA"
#       },
#       {
#          "est": -0.026809832643276535,
#          "err": 0.010785330283361916,
#          "est_label": "$\\hat{\\lambda}$",
#          "err_label": "$\\sigma_{\\lambda}$",
#          "row": 1,
#          "column": 1,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_LAMBDA"
#       },
#       {
#          "est": -0.009120271031021861,
#          "err": 0.006606438674223526,
#          "est_label": "$\\hat{\\lambda}$",
#          "err_label": "$\\sigma_{\\lambda}$",
#          "row": 2,
#          "column": 1,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_LAMBDA"
#       }
#    ],
#    "beta_est": [
#       {
#          "est": 1.0,
#          "err": 0.0,
#          "est_label": "$\\hat{\\beta}$",
#          "err_label": "$\\sigma_{\\beta}$",
#          "row": 0,
#          "column": 0,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_BETA"
#       },
#       {
#          "est": -2.376303159381835e-18,
#          "err": 0.0,
#          "est_label": "$\\hat{\\beta}$",
#          "err_label": "$\\sigma_{\\beta}$",
#          "row": 1,
#          "column": 0,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_BETA"
#       },
#       {
#          "est": -0.9977915466582689,
#          "err": 0.1277213148101388,
#          "est_label": "$\\hat{\\beta}$",
#          "err_label": "$\\sigma_{\\beta}$",
#          "row": 2,
#          "column": 0,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_BETA"
#       },
#       {
#          "est": 1.5267882422810292e-17,
#          "err": 0.0,
#          "est_label": "$\\hat{\\beta}$",
#          "err_label": "$\\sigma_{\\beta}$",
#          "row": 0,
#          "column": 1,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_BETA"
#       },
#       {
#          "est": 1.0,
#          "err": 0.0,
#          "est_label": "$\\hat{\\beta}$",
#          "err_label": "$\\sigma_{\\beta}$",
#          "row": 1,
#          "column": 1,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_BETA"
#       },
#       {
#          "est": -1.272482736344328,
#          "err": 0.11040027091865784,
#          "est_label": "$\\hat{\\beta}$",
#          "err_label": "$\\sigma_{\\beta}$",
#          "row": 2,
#          "column": 1,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_BETA"
#       }
#    ],
#    "a_est": [
#       {
#          "est": -0.1618241813127114,
#          "err": 0.04222153397138834,
#          "est_label": "$\\hat{A}$",
#          "err_label": "$\\sigma_A$",
#          "row": 0,
#          "column": 0,
#          "order": 1,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_ALPHA"
#       },
#       {
#          "est": -0.0018243213039664272,
#          "err": 0.06469110513773023,
#          "est_label": "$\\hat{A}$",
#          "err_label": "$\\sigma_A$",
#          "row": 1,
#          "column": 0,
#          "order": 1,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_ALPHA"
#       },
#       {
#          "est": 0.001922634226695719,
#          "err": 0.03962584433037339,
#          "est_label": "$\\hat{A}$",
#          "err_label": "$\\sigma_A$",
#          "row": 2,
#          "column": 0,
#          "order": 1,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_ALPHA"
#       },
#       {
#          "est": -0.09257894194621956,
#          "err": 0.03819314349803109,
#          "est_label": "$\\hat{A}$",
#          "err_label": "$\\sigma_A$",
#          "row": 0,
#          "column": 1,
#          "order": 1,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_ALPHA"
#       },
#       {
#          "est": -0.07393474116266795,
#          "err": 0.05851887482927239,
#          "est_label": "$\\hat{A}$",
#          "err_label": "$\\sigma_A$",
#          "row": 1,
#          "column": 1,
#          "order": 1,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_ALPHA"
#       },
#       {
#          "est": 0.025686114755654948,
#          "err": 0.03584511069081906,
#          "est_label": "$\\hat{A}$",
#          "err_label": "$\\sigma_A$",
#          "row": 2,
#          "column": 1,
#          "order": 1,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_ALPHA"
#       },
#       {
#          "est": 0.20833324963920077,
#          "err": 0.06709166162072111,
#          "est_label": "$\\hat{A}$",
#          "err_label": "$\\sigma_A$",
#          "row": 0,
#          "column": 2,
#          "order": 1,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_ALPHA"
#       },
#       {
#          "est": 0.057620581985163205,
#          "err": 0.1027966851870487,
#          "est_label": "$\\hat{A}$",
#          "err_label": "$\\sigma_A$",
#          "row": 1,
#          "column": 2,
#          "order": 1,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_ALPHA"
#       },
#       {
#          "est": -0.050820835255005324,
#          "err": 0.06296700970292486,
#          "est_label": "$\\hat{A}$",
#          "err_label": "$\\sigma_A$",
#          "row": 2,
#          "column": 2,
#          "order": 1,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VECM_ALPHA"
#       }
#    ],
#    "omega": [
#       {
#          "est": 0.23035243418910492,
#          "err": 0.0,
#          "est_label": "$\\hat{\\Omega}$",
#          "err_label": "$\\sigma_{\\Omega}$",
#          "row": 0,
#          "column": 0,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VAR_OMEGA"
#       },
#       {
#          "est": 0.26686273721031967,
#          "err": 0.0,
#          "est_label": "$\\hat{\\Omega}$",
#          "err_label": "$\\sigma_{\\Omega}$",
#          "row": 0,
#          "column": 1,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VAR_OMEGA"
#       },
#       {
#          "est": 0.1731301809100298,
#          "err": 0.0,
#          "est_label": "$\\hat{\\Omega}$",
#          "err_label": "$\\sigma_{\\Omega}$",
#          "row": 0,
#          "column": 2,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VAR_OMEGA"
#       },
#       {
#          "est": 0.26686273721031967,
#          "err": 0.0,
#          "est_label": "$\\hat{\\Omega}$",
#          "err_label": "$\\sigma_{\\Omega}$",
#          "row": 1,
#          "column": 0,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VAR_OMEGA"
#       },
#       {
#          "est": 0.5407716692084472,
#          "err": 0.0,
#          "est_label": "$\\hat{\\Omega}$",
#          "err_label": "$\\sigma_{\\Omega}$",
#          "row": 1,
#          "column": 1,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VAR_OMEGA"
#       },
#       {
#          "est": 0.29687911968512837,
#          "err": 0.0,
#          "est_label": "$\\hat{\\Omega}$",
#          "err_label": "$\\sigma_{\\Omega}$",
#          "row": 1,
#          "column": 2,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VAR_OMEGA"
#       },
#       {
#          "est": 0.1731301809100298,
#          "err": 0.0,
#          "est_label": "$\\hat{\\Omega}$",
#          "err_label": "$\\sigma_{\\Omega}$",
#          "row": 2,
#          "column": 0,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VAR_OMEGA"
#       },
#       {
#          "est": 0.29687911968512837,
#          "err": 0.0,
#          "est_label": "$\\hat{\\Omega}$",
#          "err_label": "$\\sigma_{\\Omega}$",
#          "row": 2,
#          "column": 1,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VAR_OMEGA"
#       },
#       {
#          "est": 0.20289990721019702,
#          "err": 0.0,
#          "est_label": "$\\hat{\\Omega}$",
#          "err_label": "$\\sigma_{\\Omega}$",
#          "row": 2,
#          "column": 2,
#          "order": 0,
#          "est_id": "ca96168f-7eb6-485f-aa20-4276ea6aa714",
#          "param_type": "VAR_OMEGA"
#       }
#    ]
# }
