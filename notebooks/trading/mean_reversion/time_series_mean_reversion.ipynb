# %% [markdown]
# # Time Series Mean Reversion
#
# Here real data is analyzed for mean reversion by using a stationary ARIMA model and a Fractional Brownian motion model

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot
from datetime import datetime
from pandas import DataFrame, read_csv

sys.path.insert(0, os.path.abspath('../../..'))

# import local modules
from lib import config
from lib.utils import extract_date_range
from lib.plots import curve, comparison, stack, periodogram, variance_agg, PlotType, mean_reversion_halflife
from lib.data import arima, adf, stats, fbm, HypothesisTestType, ou

# Config Plot Style
pyplot.style.use(config.glyfish_style)

# %% [markdown]
# ## Stationary Autoregressive Process
#
# Stationary autoregressive time series are mean reverting. Here the USD.CAD exchange rate is tested for stationarity using the ADF test. It is seen that the time series is not stationary but it is close to stationary. Using the periodogram method it is found that $H=0.48$ and variance aggregation gives $H=0.45$. The Variance ratio test

# %%
file_path = os.path.abspath('../../../data/algorithmic_trading/CAD=X.csv')
usd_cad_data = read_csv(file_path, index_col=0, parse_dates=True).sort_values(by='Date').dropna()
usd_cad_data.head()
# Out:
#               Open    High     Low   Close  Adj Close  Volume
# Date
# 2003-09-17  1.3667  1.3704  1.3636  1.3667     1.3667     0.0
# 2003-09-18  1.3660  1.3685  1.3597  1.3615     1.3615     0.0
# 2003-09-19  1.3620  1.3630  1.3457  1.3472     1.3472     0.0
# 2003-09-22  1.3413  1.3553  1.3365  1.3542     1.3542     0.0
# 2003-09-23  1.3549  1.3577  1.3458  1.3551     1.3551     0.0

# %%
date, usd_cad_close = extract_date_range(usd_cad_data.index.to_numpy(), usd_cad_data['Close'].to_numpy(), '2007-07-22', '2012-03-28')
usd_cad_close_mean = numpy.full(len(usd_cad_close), numpy.mean(usd_cad_close))

# %%
title = 'USD.CAD Exchange Rate'
comparison([usd_cad_close, usd_cad_close_mean], date, title=title, xlabel="Date", ylabel="USD.CAD", labels=['USD.CAD', 'Mean'], lw=1)

# %%
result, _ = adf.compute_adf_offset_test(usd_cad_close, max_lag=12)
result.summary()
# Out:
# ╒════════════════╤═════════════╕
# │ Test Statistic │   -1.60531  │
# ├────────────────┼─────────────┤
# │ pvalue         │    0.480923 │
# ├────────────────┼─────────────┤
# │ Lags           │    9        │
# ├────────────────┼─────────────┤
# │ Number Obs     │ 1205        │
# ╘════════════════╧═════════════╛
# ╒════════════════╤══════════════════╤══════════╕
# │ Significance   │   Critical Value │ Result   │
# ╞════════════════╪══════════════════╪══════════╡
# │ 1%             │         -3.43579 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 5%             │         -2.86394 │ Passed   │
# ├────────────────┼──────────────────┼──────────┤
# │ 10%            │         -2.56805 │ Passed   │
# ╘════════════════╧══════════════════╧══════════╛

# %% [markdown]
# ## Fractional Brownian Motion Process
#
# If a fractional brownian motion model is used on the same time series the variance ratio test can be used to test for anticorrelation and the Hurst exponent is estimated using the both the periodogram and variance aggregation methods. The Hurst parameter $H$ is evaluated using both the periodogram method and variance aggregation method. The results are $H=0.48$ and $H=0.45$ respectively. The variance ratio test for anitcorrelation passes. This is consistent with the stationarity test where ADF barley failed.

# %%
t, usd_cad_diff = stats.compute_diff(numpy.arange(len(usd_cad_close)), usd_cad_close)

# %%
title = 'USD.CAD Exchange Rate Noise'
curve(usd_cad_diff, t, title=title, xlabel="Days", ylabel="USD.CAD", lw=1)

# %%
freq, ps = stats.compute_pspec(t, usd_cad_diff)

title = 'USD.CAD Exchange Rate Noise Power Spectrum'
curve(ps, freq, lw=1, title=title, xlabel=r"$\omega$", ylabel=r"$\rho_\omega$", plot_axis_type=PlotType.LOG)

# %%
result, result_model = fbm.compute_H_estimate_periodogram(freq, ps)
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.06179
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):              0.804
# Time:                        10:21:51   Log-Likelihood:                -998.80
# No. Observations:                1213   AIC:                             2002.
# Df Residuals:                    1211   BIC:                             2012.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.3100      0.099    -33.350      0.000      -3.505      -3.115
# x1            -0.0092      0.037     -0.249      0.804      -0.082       0.063
# ==============================================================================
# Omnibus:                      171.664   Durbin-Watson:                   1.214
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              263.951
# Skew:                          -0.970   Prob(JB):                     4.83e-58
# Kurtosis:                       4.208   Cond. No.                         19.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#    "est_model": "OLS",
#    "const": {
#       "est": -3.3100215251305647,
#       "err": 0.0992511901111557,
#       "est_label": "$\\beta$",
#       "err_label": "$\\sigma_{\\beta}$",
#       "row": 0,
#       "column": 0,
#       "order": 0,
#       "est_id": "964ba59d-8654-4c3b-8182-d9e33125713b",
#       "param_type": "OLS_CONST"
#    },
#    "params": [
#       {
#          "est": -0.00918689706057186,
#          "err": 0.03695686881021254,
#          "est_label": "$\\alpha_1$",
#          "err_label": "$\\sigma_{\\alpha_1}$",
#          "row": 0,
#          "column": 1,
#          "order": 0,
#          "est_id": "964ba59d-8654-4c3b-8182-d9e33125713b",
#          "param_type": "OLS_PARAM"
#       }
#    ],
#    "r2": 5.1024770521324037e-05,
#    "param_transforms": [
#       {
#          "param": {
#             "est": 0.504593448530286,
#             "err": 0.01847843440510627,
#             "est_label": "$\\hat{\u0397}$",
#             "err_label": "$\\sigma_{\\hat{\u0397}}$",
#             "row": 0,
#             "column": 0,
#             "order": 1,
#             "est_id": "964ba59d-8654-4c3b-8182-d9e33125713b",
#             "param_type": "TRANS_PARAM"
#          }
#       }
#    ],
#    "const_transform": {
#       "param": {
#          "est": 0.0004897545448445558,
#          "err": 4.860872143816953e-05,
#          "est_label": "$\\hat{C}$",
#          "err_label": "$\\sigma_{\\hat{C}}$",
#          "row": 0,
#          "column": 0,
#          "order": 1,
#          "est_id": "964ba59d-8654-4c3b-8182-d9e33125713b",
#          "param_type": "TRANS_CONST"
#       }
#    },
#    "est_id": "964ba59d-8654-4c3b-8182-d9e33125713b",
#    "model": "$C\\omega^{1 - 2H}$"
# }

# %%
periodogram(ps, result_model, freq, title=f"USD.CAD Exchange Rate Periodogram H Estimate")

# %%
nagg = 100
m_vals, agg_var = stats.compute_agg_var(usd_cad_diff, m_max=nagg, npts=nagg)

# %%
result, result_model = fbm.compute_H_estimate_variance_aggregation(m_vals, agg_var)
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     1901.
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):           5.54e-66
# Time:                        10:21:51   Log-Likelihood:                 90.280
# No. Observations:                 100   AIC:                            -176.6
# Df Residuals:                      98   BIC:                            -171.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -4.0626      0.040   -100.872      0.000      -4.143      -3.983
# x1            -1.0775      0.025    -43.604      0.000      -1.127      -1.028
# ==============================================================================
# Omnibus:                        0.002   Durbin-Watson:                   1.788
# Prob(Omnibus):                  0.999   Jarque-Bera (JB):                0.097
# Skew:                           0.002   Prob(JB):                        0.953
# Kurtosis:                       2.847   Cond. No.                         9.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#    "est_model": "OLS",
#    "const": {
#       "est": -4.0625838464539,
#       "err": 0.040274635556716204,
#       "est_label": "$\\beta$",
#       "err_label": "$\\sigma_{\\beta}$",
#       "row": 0,
#       "column": 0,
#       "order": 0,
#       "est_id": "994b4921-0fdd-491c-b2d9-fd2aab2dc84b",
#       "param_type": "OLS_CONST"
#    },
#    "params": [
#       {
#          "est": -1.0774992054506876,
#          "err": 0.024711268691794956,
#          "est_label": "$\\alpha_1$",
#          "err_label": "$\\sigma_{\\alpha_1}$",
#          "row": 0,
#          "column": 1,
#          "order": 0,
#          "est_id": "994b4921-0fdd-491c-b2d9-fd2aab2dc84b",
#          "param_type": "OLS_PARAM"
#       }
#    ],
#    "r2": 0.9509821123092042,
#    "param_transforms": [
#       {
#          "param": {
#             "est": 0.4612503972746562,
#             "err": 0.012355634345897478,
#             "est_label": "$\\hat{\u0397}$",
#             "err_label": "$\\sigma_{\\hat{\u0397}}$",
#             "row": 0,
#             "column": 0,
#             "order": 1,
#             "est_id": "994b4921-0fdd-491c-b2d9-fd2aab2dc84b",
#             "param_type": "TRANS_PARAM"
#          }
#       }
#    ],
#    "const_transform": {
#       "param": {
#          "est": 8.657971533125297e-05,
#          "err": 3.486966481570448e-06,
#          "est_label": "$\\hat{\\sigma}^2$",
#          "err_label": "$\\sigma^2_{\\hat{\\sigma}^2}$",
#          "row": 0,
#          "column": 0,
#          "order": 1,
#          "est_id": "994b4921-0fdd-491c-b2d9-fd2aab2dc84b",
#          "param_type": "TRANS_CONST"
#       }
#    },
#    "est_id": "994b4921-0fdd-491c-b2d9-fd2aab2dc84b",
#    "model": "$\\sigma^2 m^{2\\left(H-1\\right)}$"
# }

# %%
variance_agg(agg_var, result_model, m_vals, title=f"USD.CAD Exchange Rate Aggregated Variance H Estimate")

# %%
result, result_model = fbm.compute_vr_test(usd_cad_close, HypothesisTestType.FBM_NEG_AUTO_CORR)
result.summary()
# Out:
# ╒══════════════════════╤══════════════════════════════════════╕
# │ Hypothesis Type      │ HypothesisType.LOWER_TAIL            │
# ├──────────────────────┼──────────────────────────────────────┤
# │ Hypothesis Test Type │ HypothesisTestType.FBM_NEG_AUTO_CORR │
# ├──────────────────────┼──────────────────────────────────────┤
# │ Significance         │ 10%                                  │
# ├──────────────────────┼──────────────────────────────────────┤
# │ Lower Critical Value │ -1.282                               │
# ╘══════════════════════╧══════════════════════════════════════╛
# ╒═════╤════════╤══════════╤══════════╕
# │   s │   Z(s) │   pvalue │ Result   │
# ╞═════╪════════╪══════════╪══════════╡
# │   4 │  0.415 │    0.661 │ Passed   │
# ├─────┼────────┼──────────┼──────────┤
# │   6 │  0.713 │    0.762 │ Passed   │
# ├─────┼────────┼──────────┼──────────┤
# │  10 │  0.081 │    0.532 │ Passed   │
# ├─────┼────────┼──────────┼──────────┤
# │  16 │ -0.581 │    0.281 │ Passed   │
# ├─────┼────────┼──────────┼──────────┤
# │  24 │ -0.789 │    0.215 │ Passed   │
# ╘═════╧════════╧══════════╧══════════╛

# %%
print(result_model.to_json(pretty=True))
# Out:
# {
#     "status": "FAILED",
#     "hyp_type": "LOWER_TAIL",
#     "hyp_test_type": "NEG_AUTO_CORR",
#     "test_data": [
#         {
#             "status": "PASSED",
#             "stat": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$Z(s)$",
#                 "value": 0.4150846799152601
#             },
#             "pval": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$p-value$",
#                 "value": 0.6609600429403613
#             },
#             "params": [
#                 {
#                     "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                     "label": "$s$",
#                     "value": 4
#                 }
#             ],
#             "sig": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "10%",
#                 "value": 0.1
#             },
#             "lower": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$Z_L(s)$",
#                 "value": -1.2815515655446004
#             },
#             "upper": null,
#             "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$Z(s)$",
#                 "value": 0.713383357338593
#             },
#             "pval": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$p-value$",
#                 "value": 0.762195715661513
#             },
#             "params": [
#                 {
#                     "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                     "label": "$s$",
#                     "value": 6
#                 }
#             ],
#             "sig": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "10%",
#                 "value": 0.1
#             },
#             "lower": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$Z_L(s)$",
#                 "value": -1.2815515655446004
#             },
#             "upper": null,
#             "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$Z(s)$",
#                 "value": 0.0809794752112961
#             },
#             "pval": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$p-value$",
#                 "value": 0.5322708623515456
#             },
#             "params": [
#                 {
#                     "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                     "label": "$s$",
#                     "value": 10
#                 }
#             ],
#             "sig": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "10%",
#                 "value": 0.1
#             },
#             "lower": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$Z_L(s)$",
#                 "value": -1.2815515655446004
#             },
#             "upper": null,
#             "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$Z(s)$",
#                 "value": -0.5805812084925102
#             },
#             "pval": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$p-value$",
#                 "value": 0.2807613700901754
#             },
#             "params": [
#                 {
#                     "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                     "label": "$s$",
#                     "value": 16
#                 }
#             ],
#             "sig": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "10%",
#                 "value": 0.1
#             },
#             "lower": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$Z_L(s)$",
#                 "value": -1.2815515655446004
#             },
#             "upper": null,
#             "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810"
#         },
#         {
#             "status": "PASSED",
#             "stat": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$Z(s)$",
#                 "value": -0.7890339162283817
#             },
#             "pval": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$p-value$",
#                 "value": 0.21504609191005108
#             },
#             "params": [
#                 {
#                     "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                     "label": "$s$",
#                     "value": 24
#                 }
#             ],
#             "sig": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "10%",
#                 "value": 0.1
#             },
#             "lower": {
#                 "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810",
#                 "label": "$Z_L(s)$",
#                 "value": -1.2815515655446004
#             },
#             "upper": null,
#             "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810"
#         }
#     ],
#     "desc": "Negative Autocorrelation Test",
#     "test_id": "1652cab8-03c8-4e9b-8ca7-2fc28001e810"
# }

# %% [markdown]
# ## Half-Life For Mean Reversion
#
# The $\text{AR}(1)$ process with constant offset is defined by,
#
# $
# \begin{align}
# X_t = \varphi X_{t-1} + \mu + \sigma \varepsilon_t
# \end{align}
# \tag{1}
# $
#
# where $\varepsilon_t \sim \text{Normal}(0, 1)$. Subtracting $X_{t-1}$ from both sides gives,
#
# $
# \begin{align}
# \Delta X_t = \left(\varphi - 1 \right) X_{t-1} \Delta t + \mu\Delta t + \sigma \sqrt{\Delta t} \varepsilon_t
# \end{align}
# \tag{2}
# $
#
# This can be reparameterized to,
#
# $
# \begin{align}
# \Delta X_t = \lambda \left(\frac{\mu}{\lambda} + X_{t-1}\right)\Delta t + \sigma\sqrt{\Delta t} \varepsilon_t
# \end{align}
# \tag{3}
# $
#
# where $\lambda = \varphi - 1$.
#
# The continuous differential form of this equation is the Ornstein-Uhlenbeck SDE,
#
# $
# \begin{align}
# dX_t = \lambda \left(\frac{\mu}{\lambda} + X_t \right) dt + \sigma dB_t
# \end{align}
# \tag{4}
# $
#
# where $dB_t \sim \text{Normal}(0, dt)$. The Ornstein-Uhlenbeck SDE models a mean reverting random process and can be solved using the integration factor, $e^{-\lambda t}$
#
# $
# \begin{align}
# X_t = X_0 e^{\lambda t} + \frac{\mu}{\lambda} \left( 1 - e^{\lambda t} \right) + \sigma \int_0^t e^{\lambda\left( t - s \right)} dB_s
# \end{align}
# \tag{5}
# $
#
# The mean value is given by,
#
# $
# \begin{align}
# \text{E}\left[ X_t \right] = X_0 e^{\lambda t} + \frac{\mu}{\lambda} \left( 1 - e^{\lambda t} \right)
# \end{align}
# \tag{6}
# $
#
# For the limit $t \to \infty$ a finite mean value requires $\lambda < 0$,
#
# $
# \begin{align}
# \lim_{t\to\infty}\text{E}\left[ X_t \right] = -\frac{\mu}{\lambda}
# \end{align}
# \tag{7}
# $
#
# The half life of mean decay is the time to reach $\frac{1}{2}$ the $t \to \infty$ value from the initial value. This defines the timescale of the Ornstein-Uhlenbeck process. If $t_H$ denotes the half life. It follows that $X_{t_H}$ is given by,
#
# $
# \begin{align}
# X_{t_H} = X_0 - \frac{1}{2}\left(\frac{\mu}{\lambda} + X_0 \right)
# \end{align}
# \tag{8}
# $
#
# Using $Eq(7)$ and $Eq(8)$ and solving for $t_H$ gives,
#
# $
# \begin{align}
# t_H = -\frac{\ln{2}}{\lambda}
# \end{align}
# \tag{9}
# $
#
# $\lambda$ can be evaluated by using regression on the equation,
#
# $
# \begin{align}
# \Delta X_t = \lambda X_{t-1}\Delta t + \mu\Delta t + \sigma \sqrt{\Delta t}\varepsilon_t
# \end{align}
# \tag{10}
# $

# %%
title = 'USD.CAD Exchange Rate'
xt = usd_cad_close - usd_cad_close_mean
curve(xt, date, title=title, xlabel="Date", ylabel="USD.CAD", labels=['USD.CAD', 'Mean'], lw=1)

# %%
result, result_model = ou.compute_mean_half_life_estimate(xt)
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.256
# Date:                Wed, 03 Jan 2024   Prob (F-statistic):             0.0714
# Time:                        10:21:52   Log-Likelihood:                 4057.3
# No. Observations:                1214   AIC:                            -8111.
# Df Residuals:                    1212   BIC:                            -8100.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.542e-05      0.000     -0.185      0.853      -0.001       0.000
# x1            -0.0056      0.003     -1.804      0.071      -0.012       0.000
# ==============================================================================
# Omnibus:                      113.415   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              433.965
# Skew:                           0.381   Prob(JB):                     5.83e-95
# Kurtosis:                       5.828   Cond. No.                         12.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
print(result_model.to_json(True))
# Out:
# {
#    "est_model": "OLS",
#    "const": {
#       "est": -4.541725118564352e-05,
#       "err": 0.00024578554230089087,
#       "est_label": "$\\beta$",
#       "err_label": "$\\sigma_{\\beta}$",
#       "row": 0,
#       "column": 0,
#       "order": 0,
#       "est_id": "86ddc77b-df84-4c18-a2a3-308b8ae3780f",
#       "param_type": "OLS_CONST"
#    },
#    "params": [
#       {
#          "est": -0.005568763382202106,
#          "err": 0.0030862402003987216,
#          "est_label": "$\\alpha_1$",
#          "err_label": "$\\sigma_{\\alpha_1}$",
#          "row": 0,
#          "column": 1,
#          "order": 0,
#          "est_id": "86ddc77b-df84-4c18-a2a3-308b8ae3780f",
#          "param_type": "OLS_PARAM"
#       }
#    ],
#    "r2": 0.0026791089715498817,
#    "param_transforms": [
#       {
#          "param": {
#             "est": 124.47057506075036,
#             "err": 68.98229753251394,
#             "est_label": "$t_{1/2}$",
#             "err_label": "$\\sigma_{t_H}$",
#             "row": 0,
#             "column": 0,
#             "order": 1,
#             "est_id": "86ddc77b-df84-4c18-a2a3-308b8ae3780f",
#             "param_type": "TRANS_PARAM"
#          }
#       },
#       {
#          "param": {
#             "est": -0.005568763382202106,
#             "err": 0.0030862402003987216,
#             "est_label": "$\\lambda$",
#             "err_label": "$\\sigma_\\lambda$",
#             "row": 1,
#             "column": 0,
#             "order": 1,
#             "est_id": "86ddc77b-df84-4c18-a2a3-308b8ae3780f",
#             "param_type": "TRANS_PARAM"
#          }
#       }
#    ],
#    "const_transform": {
#       "param": {
#          "est": -4.541725118564352e-05,
#          "err": 0.00024578554230089087,
#          "est_label": "$\\mu$",
#          "err_label": "$\\sigma_{\\mu}$",
#          "row": 0,
#          "column": 0,
#          "order": 1,
#          "est_id": "86ddc77b-df84-4c18-a2a3-308b8ae3780f",
#          "param_type": "TRANS_CONST"
#       }
#    },
#    "est_id": "86ddc77b-df84-4c18-a2a3-308b8ae3780f",
#    "model": "$\\Delta X_t = \\lambda X_{t-1} \\Delta t + \\mu \\Delta t + \\sqrt{\\Delta t} \\varepsilon_t$"
# }

# %%
title = f"USD.CAD Exchange Rate Mean Reversion Half Life Estimate"
mean_reversion_halflife(xt, result_model, title=title, result_loc='upper right')

# %% [markdown]
# # Linear Trading Strategy
#
# A linear trading strategy can be defined as follows for a mean reverting price series, $y$. The normalized deviation of the price, Z-Score, is defined by
#
# $
# \begin{align}
# Z = \frac{y - \text{moving\_avg}(y, \text{halflife})}{\text{moving\_std}(y, \text{halflife})}
# \end{align}
# \tag{1}
# $
#
# Where $\text{halflife}$ is the estimated halflife of mean reversion for price series and **moving_avg(y, halflife)** and **moving_std(y, halflife)** are the moving standard deviation and mean computed over the window defined by the mean reversion halflife. The trading strategy involves holding a number of units of the price series proportional to the negative value of the Z-score. It follows that the profit and loss curve for a single unit of the mean reverting asset is given by,
#
# $
# \begin{align}
# P&L = -\text{lag}(Z, 1) * \frac{(y - \text{lag}(y, 1))}{\text{lag}(y, 1)}
# \end{align}
# \tag{1}
# $
#
# where $\text{lag}(V, nlag)$ applies the specified number of lags to the specified variable. Here the first term in the definition of P&L specifies the number of units held of the asset and the second term represents the the relative change in price at the current time step.

# %%
mean_reversion_half_life = result_model.param_transforms[0].param.est
title = f"USD.CAD Exchange Rate: $t_{{1/2}} = {mean_reversion_half_life:.0f}$ days"
_, cmean = stats.compute_cumu_mean(date, usd_cad_close)
_, csd = stats.compute_cumu_sd(date, usd_cad_close)
labels = ['USD.CAD', 'Cumulative Mean', r"Cumulative $\sigma$"]
colors = ['#0067C4', '#FF9500', '#5600C9', '#5600C9']
comparison([usd_cad_close, cmean, cmean + csd, cmean - csd], date, title=title, xlabel="Day", ylabel="USD.CAD", labels=labels, colors=colors, lw=1)

# %%
mean_reversion_half_life = int(result_model.param_transforms[0].param.est)
avg_date, moving_avg = stats.compute_moving_avg(date, usd_cad_close, mean_reversion_half_life)
title = f'USD.CAD Exchange Rate Moving Average: $t_{{1/2}} = {mean_reversion_half_life:.0f}$ days'
curve(moving_avg, avg_date, title=title, xlabel="Day", ylabel="Moving Average", lw=1)

# %%
mean_reversion_half_life = int(result_model.param_transforms[0].param.est)
std_date, moving_std = stats.compute_moving_std(date, usd_cad_close, mean_reversion_half_life)
title = f'USD.CAD Exchange Rate Moving Standard Deviation: $t_{{1/2}} = {mean_reversion_half_life:.0f}$ days'
curve(moving_std, std_date, title=title, xlabel="Day", ylabel="Moving Standard Deviation", lw=1)

# %%
mean_reversion_half_life = int(result_model.param_transforms[0].param.est)
zdate, zscore = stats.compute_zscore(date, usd_cad_close, mean_reversion_half_life)
title = f'USD.CAD Exchange Rate Z-Score: $t_{{1/2}} = {mean_reversion_half_life:.0f}$ days'
curve(zscore, zdate, title=title, xlabel=f"Day", ylabel="Z-Score", lw=1)

# %%
mean_reversion_half_life = int(result_model.param_transforms[0].param.est)
frac_date, frac_purchase = stats.compute_fractional_price_change(date, usd_cad_close, mean_reversion_half_life)
title = f'USD.CAD Exchange Fractional Price Change: $t_{{1/2}} = {mean_reversion_half_life:.0f}$ days'
curve(frac_purchase, frac_date, title=title, xlabel=f"Day", ylabel="Fractional Price Change", lw=1)
