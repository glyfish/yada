# %% [markdown]
# # Z-Score Strategy
#
# The Z-Score strategy is described in *Algorithmic Trading* by *Ernest P. Chan*. The strategy uses the Z-Score computed from a moving average and moving standard deviation with window equal to the half-life of mean reversion, namely,
#
# $
# \begin{align}
# Z = \frac{y - \text{moving\_avg}(y, \text{halflife})}{\text{moving\_std}(y, \text{halflife})}
# \end{align}
# \tag{1}
# $
#
# The strategy involves holding a position equal to a multiple of the negative of the Z-Score. If it is negative a long position is held. For this case the the current price is below the mean value. If it is positive two options are available and investigated. In the first no position is held and in the second a short position is held that is a multiple of the Z-Score. For this case the price is above the mean.</br>
#
# The aim of the strategy is to reduce the risk of holding a relatively large position when the mean reverts. The strategy holds a larger long or short position the further the current price is from the mean value and as the price approaches the mean the position is reduced.</br>
#
# The asset analyzed is the USD/CAD exchange rate, CAD=X.
#
# ## Strategy Exit Position on Positive Z-Score
#
# This version of the strategy holds a short position for positive z-score and nothing for a negative z-score. The purpose of this test is to look at the accounting for short trades.

# %%
# %reload_ext autoreload
# %autoreload 2

# import system modules and set local import path
import os
import sys
import numpy
from matplotlib import pyplot

sys.path.insert(0, os.path.abspath('../../..'))

# import local modules
from lib import config
import lib.plots.dash.backtrader as dash
from lib.plots import (curve, bar, twinx_bar_line, fcurve_scatter_comparison, positive_negative_bar, 
                       zscore_backtest)
from lib.data import stats
from lib.data.backtrader import compute_mean_reversion_halflife
from lib.db import BacktestDb

# Config Plot Style
pyplot.style.use(config.glyfish_style)

# %%
db = BacktestDb()
backtest_id = 'BVsa7fC59ey7'
file_root = '../../../data/algorithmic_trading'

# %%
# db.insert_yahoo_price_series("CAD=X", file_root)

# %% [markdown]
# ## Asset CAD=X

# %%
price_series_data = db.fetch_price_series("CAD=X", start_date='2007-07-22', end_date='2012-03-28')
price_series_data.head()
# Out:
#   ticker        date  open_price  high_price  low_price  close_price
# 0  CAD=X  2007-07-23      1.0479     1.04790     1.0424      1.04676  \
# 1  CAD=X  2007-07-24      1.0466     1.04726     1.0340      1.03660
# 2  CAD=X  2007-07-25      1.0366     1.04455     1.0342      1.04180
# 3  CAD=X  2007-07-26      1.0418     1.05680     1.0403      1.05360
# 4  CAD=X  2007-07-27      1.0536     1.06530     1.0501      1.06390
#
#    adj_close_price  volume
# 0          1.04676     0.0
# 1          1.03660     0.0
# 2          1.04180     0.0
# 3          1.05360     0.0
# 4          1.06390     0.0

# %%
dash.price_series(price_series_data)

# %% [markdown]
# ### Mean Reversion Halflife

# %%
mean_reversion_half_life, result, _ = compute_mean_reversion_halflife(price_series_data.close_price.to_numpy())
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.294
# Date:                Sat, 25 May 2024   Prob (F-statistic):             0.0698
# Time:                        18:42:07   Log-Likelihood:                 4061.0
# No. Observations:                1215   AIC:                            -8118.
# Df Residuals:                    1213   BIC:                            -8108.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.194e-05      0.000     -0.171      0.864      -0.001       0.000
# x1            -0.0056      0.003     -1.815      0.070      -0.012       0.000
# ==============================================================================
# Omnibus:                      113.526   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              434.957
# Skew:                           0.380   Prob(JB):                     3.55e-95
# Kurtosis:                       5.831   Cond. No.                         12.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
mean_reversion_half_life
# Out:
# 123.81305867441176

# %% [markdown]
# ### Asset Price

# %%
asset_price_data = db.fetch_asset_price(backtest_id)
asset_price_data.head()
# Out:
#          date        run_id ticker   ensemble_id  open_price  high_price
# 0  2008-01-15  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64        1.02        1.02  \
# 1  2008-01-16  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64        1.02        1.03
# 2  2008-01-17  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64        1.02        1.03
# 3  2008-01-18  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64        1.03        1.03
# 4  2008-01-21  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64        1.03        1.04
#
#    low_price  close_price
# 0       1.01         1.02
# 1       1.02         1.02
# 2       1.02         1.03
# 3       1.02         1.03
# 4       1.03         1.04

# %%
dash.asset_price(asset_price_data)

# %% [markdown]
# ### Balance

# %%
broker_data = db.fetch_broker(backtest_id)
broker_data.head()
# Out:
#          date        run_id   ensemble_id     cash    value
# 0  2008-01-15  BVsa7fC59ey7  gnEYDFRFJF64  1000.00  1000.00
# 1  2008-01-16  BVsa7fC59ey7  gnEYDFRFJF64  1032.64  1000.00
# 2  2008-01-17  BVsa7fC59ey7  gnEYDFRFJF64  1033.66   999.67
# 3  2008-01-18  BVsa7fC59ey7  gnEYDFRFJF64  1061.47   999.67
# 4  2008-01-21  BVsa7fC59ey7  gnEYDFRFJF64  1062.50   999.06

# %%
dash.cash_value(broker_data)

# %% [markdown]
# ### Position

# %%
position_data = db.fetch_position(backtest_id)
position_data.tail()
# Out:
#            date        run_id ticker   ensemble_id  adjbase     price
# 467  2012-01-12  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64     1.02  1.025249  \
# 468  2012-01-13  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64     1.02  1.025249
# 469  2012-01-16  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64     1.02  1.025249
# 470  2012-01-17  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64     1.02  1.025249
# 471  2012-01-18  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64     1.01  1.025249
#
#      price_orig  size  upclosed  upopened  updt
# 467    1.025249   -47       2.0       0.0  None
# 468    1.025249   -46       1.0       0.0  None
# 469    1.025249   -45       1.0       0.0  None
# 470    1.025249   -44       1.0       0.0  None
# 471    1.025249   -42       2.0       0.0  None

# %%
dash.position(position_data)

# %%
dash.position_value(position_data)

# %% [markdown]
# ### Z-Score Indicator

# %%
zscore_data = db.fetch_zscore_indicator(backtest_id)
zscore_data.head()
# Out:
#          date        run_id indicator   ensemble_id ticker    zscore
# 0  2008-01-15  BVsa7fC59ey7    zscore  gnEYDFRFJF64  CAD=X  0.328399  \
# 1  2008-01-16  BVsa7fC59ey7    zscore  gnEYDFRFJF64  CAD=X  0.336484
# 2  2008-01-17  BVsa7fC59ey7    zscore  gnEYDFRFJF64  CAD=X  0.608822
# 3  2008-01-18  BVsa7fC59ey7    zscore  gnEYDFRFJF64  CAD=X  0.611988
# 4  2008-01-21  BVsa7fC59ey7    zscore  gnEYDFRFJF64  CAD=X  0.886193
#
#    half_life  stake_multiple
# 0        124             100
# 1        124             100
# 2        124             100
# 3        124             100
# 4        124             100

# %%
dash.zscore_indicator_position(zscore_data, position_data)

# %% [markdown]
# ### Orders

# %%
orders_data = db.fetch_orders(backtest_id)
orders_data.head()
# Out:
#          date        run_id ticker   ensemble_id order_status order_type
# 0  2008-01-16  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Submitted       Sell  \
# 1  2008-01-16  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64     Accepted       Sell
# 2  2008-01-16  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed       Sell
# 3  2008-01-17  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Submitted       Sell
# 4  2008-01-17  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64     Accepted       Sell
#
#      trade_id  price  value  size  commission  pnl exec_type
# 0  2473638660   1.02   0.00   -32         0.0  0.0    Market
# 1  2473638660   1.02   0.00   -32         0.0  0.0    Market
# 2  2473638660   1.02 -32.64   -32         0.0  0.0    Market
# 3  2473638660   1.02   0.00    -1         0.0  0.0    Market
# 4  2473638660   1.02   0.00    -1         0.0  0.0    Market

# %%
completed_orders = orders_data.query('order_status == "Completed"')
completed_orders.head()
# Out:
#           date        run_id ticker   ensemble_id order_status order_type
# 2   2008-01-16  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed       Sell  \
# 5   2008-01-17  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed       Sell
# 8   2008-01-18  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed       Sell
# 11  2008-01-21  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed       Sell
# 14  2008-01-22  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed       Sell
#
#       trade_id  price  value  size  commission  pnl exec_type
# 2   2473638660   1.02 -32.64   -32         0.0  0.0    Market
# 5   2473638660   1.02  -1.02    -1         0.0  0.0    Market
# 8   2473638660   1.03 -27.81   -27         0.0  0.0    Market
# 11  2473638660   1.03  -1.03    -1         0.0  0.0    Market
# 14  2473638660   1.04 -28.08   -27         0.0  0.0    Market

# %%
buy_orders = completed_orders.query('order_type == "Buy" and order_status == "Completed"')
buy_orders.head()
# Out:
#           date        run_id ticker   ensemble_id order_status order_type
# 17  2008-01-23  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed        Buy  \
# 20  2008-01-24  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed        Buy
# 23  2008-01-25  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed        Buy
# 35  2008-02-11  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed        Buy
# 53  2008-02-21  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed        Buy
#
#       trade_id  price      value  size  commission       pnl exec_type
# 17  2473638660   1.03 -26.762273    26         0.0 -0.017727    Market
# 20  2473638660   1.02 -26.762273    26         0.0  0.242273    Market
# 23  2473638660   1.00 -37.055455    36         0.0  1.055455    Market
# 35  1182194663   1.00 -25.250000    25         0.0  0.250000    Market
# 53   230867586   1.01 -33.473289    33         0.0  0.143289    Market

# %%
sell_orders = orders_data.query('order_type == "Sell" and order_status == "Completed"')
sell_orders.head()
# Out:
#           date        run_id ticker   ensemble_id order_status order_type
# 2   2008-01-16  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed       Sell  \
# 5   2008-01-17  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed       Sell
# 8   2008-01-18  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed       Sell
# 11  2008-01-21  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed       Sell
# 14  2008-01-22  BVsa7fC59ey7  CAD=X  gnEYDFRFJF64    Completed       Sell
#
#       trade_id  price  value  size  commission  pnl exec_type
# 2   2473638660   1.02 -32.64   -32         0.0  0.0    Market
# 5   2473638660   1.02  -1.02    -1         0.0  0.0    Market
# 8   2473638660   1.03 -27.81   -27         0.0  0.0    Market
# 11  2473638660   1.03  -1.03    -1         0.0  0.0    Market
# 14  2473638660   1.04 -28.08   -27         0.0  0.0    Market

# %%
dash.orders(orders_data, asset_price_data)

# %%
dash.order_pnl(orders_data)

# %%
dash.order_value(orders_data)

# %%
dash.returns(orders_data)

# %%
zscore_backtest(broker=broker_data, zscore_indicator=zscore_data, asset=asset_price_data, position=position_data, 
                     orders=orders_data, strategy="Backtest using Short Z-Score Strategy")
